# %% [markdown]
# <h1>Tahminsel Analiz</h1>

# %% [markdown]
# Geçmiş verilere dayanarak gelecekteki olayları tahmin etmek için kullanılan bir analiz türüdür. Zaman serisi analizi, makine öğrenimi modelleri gibi yöntemlerle yapılabilir.

# %% [markdown]
# Örnek: Bir perakende şirketinin günlük satış verilerini kullanarak gelecek bir haftanın satışlarını tahmin etmeye çalışalım.

# %% [markdown]
# To Do List:
#
# -> Kütüphaneleri tanımla
#
# -> Örnek veri seti oluştur
#
# -> Verileri df ye dönüştür
#
# -> Bağımsız ve bağımlı değişkenleri ayır
#
# -> Verileri eğitim ve test setine ayır
#
# -> Lineer regresyon modelini oluştur ve eğit
#
# -> Gelecek hafta satışlarını tahmin et

# %%
# 1)

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# sklearn.model_selection kütüphanesi, veri setini eğitim ve test setlerine bölmek ve çeşitli çapraz doğrulama stratejileri uygulamak için kullanılır. train_test_split fonksiyonu, veri setini rastgele eğitim ve test alt kümelerine bölmek için kullanılır. Bu, modelin eğitim verileri üzerinde öğrenmesini sağlar ve ardından test verileri üzerinde değerlendirilmesine olanak tanır.

# %% [markdown]
# sklearn.linear_model kütüphanesi, doğrusal regresyon, lasso regresyon, ridge regresyon gibi doğrusal regresyon modellerini içerir. LinearRegression sınıfı, doğrusal regresyon modelini oluşturmak için kullanılır. Bu model, bağımlı değişken ile bağımsız değişkenler arasındaki ilişkiyi modeller ve bu ilişkiyi temsil eden bir doğrusal denklemi öğrenir.

# %%
# 2)

data = {
    'Gün' : [1,2,3,4,5,6,7],
    'Satışlar' : [100,120,110,130,140,150,160]
}

# %%
# 3)

df = pd.DataFrame(data)
df
# Out:
#    Gün  Satışlar
# 0    1       100
# 1    2       120
# 2    3       110
# 3    4       130
# 4    5       140
# 5    6       150
# 6    7       160

# %%
# 4)

x = df[['Gün']]
y = df[['Satışlar']]

# %%
# 5)

x_train , x_test , y_train , y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# train_test_split: veriyi eğitim ve test setlerine bölmek için kullanılır <br> test_size=0.2: Bu, test setinin oranını belirtir. Burada, veri setinin %20'si test setine ayrılacak şekilde ayarlanmıştır. Diğer bir deyişle, veri setinin %80'i eğitim setine ayrılacaktır. <br> random_state=0: Bu, rastgele sayı üreteci için bir tohum değeridir. Bu sayede, fonksiyonun her çağrıldığında aynı bölme yapılarak tekrarlanabilir sonuçlar elde edilir. Eğer bu parametre belirtilmezse, her çağrıda farklı bölme yapılarak farklı sonuçlar elde edilir.

# %%
# 6)

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# model.fit(x_train, y_train): Bu yöntem, oluşturulan doğrusal regresyon modelini eğitmek için kullanılır. x_train bağımsız değişkenlerini ve y_train bağımlı değişkenlerini kullanarak, modelin eğitimini gerçekleştirir. Bu, bağımsız değişkenler ve bağımlı değişken arasındaki ilişkiyi temsil eden katsayıları (eğim) ve kesme noktasını (düzeltme terimi) hesaplar.

# %%
# 7)

hafta = pd.DataFrame({'Gün' : [8,9,10,11,12,13,14]})

tahminler = model.predict(hafta)

print("Gelecek haftanın tahmini satışları:")
print(tahminler)
# Out:
# Gelecek haftanın tahmini satışları:
# [[167.90697674]
#  [176.97674419]
#  [186.04651163]
#  [195.11627907]
#  [204.18604651]
#  [213.25581395]
#  [222.3255814 ]]

# %% [markdown]
# model.predict(hafta): Bu yöntem, modeli kullanarak tahminler yapmak için kullanılır. Model, verilen girdi değerlerine (bağımsız değişkenlere) dayanarak tahminler üretir. Burada, hafta DataFrame'i, tahmin yapılacak günlerin bağımsız değişkenlerini içerir. Model, bu bağımsız değişkenlere dayanarak bağımlı değişkenin tahminlerini üretir.
